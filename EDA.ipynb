# %%
# !pip3 install pandas
# !pip3 install openpyxl
# !pip3 install SQLAlchemy
# !pip3 seaborn
# !pip3 matplotlib
# !pip3 streamlit

# %%
import pandas as pd
import openpyxl
import numpy as np

df = pd.read_excel(r"C:\Users\mahes\OneDrive\Desktop\ola_project\OLA_data.xlsx")
print(df.head())
print(df.shape)
# Out:
#                  Date      Time     Booking_ID        Booking_Status  \
# 0 2024-07-26 14:00:00  14:00:00  CNR7153255142    Canceled by Driver
# 1 2024-07-25 22:20:00  22:20:00  CNR2940424040               Success
# 2 2024-07-30 19:59:00  19:59:00  CNR2982357879               Success
# 3 2024-07-22 03:15:00  03:15:00  CNR2395710036  Canceled by Customer
# 4 2024-07-02 09:02:00  09:02:00  CNR1797421769               Success
#
#   Customer_ID Vehicle_Type Pickup_Location Drop_Location  V_TAT  C_TAT  \
# 0   CID713523  Prime Sedan     Tumkur Road      RT Nagar    NaN    NaN
# 1   CID225428         Bike     Magadi Road       Varthur  203.0   30.0
# 2   CID270156    Prime SUV   Sahakar Nagar       Varthur  238.0  130.0
# 3   CID581320        eBike      HSR Layout   Vijayanagar    NaN    NaN
# 4   CID939555         Mini     Rajajinagar   Chamarajpet  252.0   80.0
#
#                      Canceled_Rides_by_Customer      Canceled_Rides_by_Driver  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 103024 entries, 0 to 103023
# Data columns (total 20 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   Date                        103024 non-null  datetime64[us]
#  1   Time                        103024 non-null  object
#  2   Booking_ID                  103024 non-null  str
#  3   Booking_Status              103024 non-null  str
#  4   Customer_ID                 103024 non-null  str
#  5   Vehicle_Type                103024 non-null  str
#  6   Pickup_Location             103024 non-null  str
#  7   Drop_Location               103024 non-null  str
#  8   V_TAT                       63967 non-null   float64
#  9   C_TAT                       63967 non-null   float64
#  10  Canceled_Rides_by_Customer  10499 non-null   str
#  11  Canceled_Rides_by_Driver    18434 non-null   str
#  12  Incomplete_Rides            63967 non-null   str
# ...

# %%
df.drop(columns=["Vehicle Images"], inplace=True)

# %%
duplicate_count = df.duplicated().sum()

print("Duplicate rows:", duplicate_count)
# Out:
# Duplicate rows: 0

# %% [markdown]
# ## change date and time data type

# %%
df["Date"]= pd.to_datetime(df["Date"], errors="coerce")
df["Time"]= pd.to_datetime(df["Time"],format="%H:%M:%S", errors="coerce")

# %% [markdown]
# ## Handling missing values

# %%
print(df.isnull().sum())
# Out:
# Date                              0
# Time                              0
# Booking_ID                        0
# Booking_Status                    0
# Customer_ID                       0
# Vehicle_Type                      0
# Pickup_Location                   0
# Drop_Location                     0
# V_TAT                         39057
# C_TAT                         39057
# Canceled_Rides_by_Customer    92525
# Canceled_Rides_by_Driver      84590
# Incomplete_Rides              39057
# Incomplete_Rides_Reason       99098
# Booking_Value                     0
# Payment_Method                39057
# Ride_Distance                     0
# Driver_Ratings                39057
# Customer_Rating               39057
# dtype: int64

# %%
print(df['Incomplete_Rides'].unique())
# Out:
# <StringArray>
# [nan, 'No', 'Yes']
# Length: 3, dtype: str

# %% [markdown]
# # Filling categorical data

# %%
missing_columns = [
    "Canceled_Rides_by_Customer",
    "Canceled_Rides_by_Driver",
    "Incomplete_Rides",
    "Incomplete_Rides_Reason",
    "Payment_Method"
]

for col in missing_columns:
    df[col] = df[col].fillna("Not applicable")

# %% [markdown]
# ## Filling numerical columns

# %%
df["Driver_Ratings"] = df["Driver_Ratings"].fillna(
    df["Driver_Ratings"].median()
)

df["Customer_Rating"] = df["Customer_Rating"].fillna(
    df["Customer_Rating"].median()
)

# %%
df["V_TAT"] = df["V_TAT"].fillna(
    df["V_TAT"].median()
)
df["C_TAT"] = df["C_TAT"].fillna(
    df["C_TAT"].median()
)

# %%
df.isnull().sum()
# Out:
# Date                          0
# Time                          0
# Booking_ID                    0
# Booking_Status                0
# Customer_ID                   0
# Vehicle_Type                  0
# Pickup_Location               0
# Drop_Location                 0
# V_TAT                         0
# C_TAT                         0
# Canceled_Rides_by_Customer    0
# Canceled_Rides_by_Driver      0
# Incomplete_Rides              0
# Incomplete_Rides_Reason       0
# Booking_Value                 0
# Payment_Method                0
# Ride_Distance                 0
# Driver_Ratings                0
# Customer_Rating               0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 103024 entries, 0 to 103023
# Data columns (total 19 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   Date                        103024 non-null  datetime64[us]
#  1   Time                        103024 non-null  datetime64[us]
#  2   Booking_ID                  103024 non-null  str
#  3   Booking_Status              103024 non-null  str
#  4   Customer_ID                 103024 non-null  str
#  5   Vehicle_Type                103024 non-null  str
#  6   Pickup_Location             103024 non-null  str
#  7   Drop_Location               103024 non-null  str
#  8   V_TAT                       103024 non-null  float64
#  9   C_TAT                       103024 non-null  float64
#  10  Canceled_Rides_by_Customer  103024 non-null  str
#  11  Canceled_Rides_by_Driver    103024 non-null  str
#  12  Incomplete_Rides            103024 non-null  str
# ...

# %%
print(df.head())
# Out:
#                  Date                Time     Booking_ID  \
# 0 2024-07-26 14:00:00 1900-01-01 14:00:00  CNR7153255142
# 1 2024-07-25 22:20:00 1900-01-01 22:20:00  CNR2940424040
# 2 2024-07-30 19:59:00 1900-01-01 19:59:00  CNR2982357879
# 3 2024-07-22 03:15:00 1900-01-01 03:15:00  CNR2395710036
# 4 2024-07-02 09:02:00 1900-01-01 09:02:00  CNR1797421769
#
#          Booking_Status Customer_ID Vehicle_Type Pickup_Location  \
# 0    Canceled by Driver   CID713523  Prime Sedan     Tumkur Road
# 1               Success   CID225428         Bike     Magadi Road
# 2               Success   CID270156    Prime SUV   Sahakar Nagar
# 3  Canceled by Customer   CID581320        eBike      HSR Layout
# 4               Success   CID939555         Mini     Rajajinagar
#
#   Drop_Location  V_TAT  C_TAT                    Canceled_Rides_by_Customer  \
# 0      RT Nagar  168.0   85.0                                Not applicable
# ...

# %%
df.to_excel("Cleaned_Ola_data.xlsx",index=False)
print("Data cleaning completed")
# Out:
# Data cleaning completed

# %%
import pandas as pd
import openpyxl
import numpy as np

df = pd.read_excel(r"C:\Users\mahes\OneDrive\Desktop\ola_project\Cleaned_Ola_data.xlsx")
print(df.head())
# Out:
#                  Date                Time     Booking_ID  \
# 0 2024-07-26 14:00:00 1900-01-01 14:00:00  CNR7153255142
# 1 2024-07-25 22:20:00 1900-01-01 22:20:00  CNR2940424040
# 2 2024-07-30 19:59:00 1900-01-01 19:59:00  CNR2982357879
# 3 2024-07-22 03:15:00 1900-01-01 03:15:00  CNR2395710036
# 4 2024-07-02 09:02:00 1900-01-01 09:02:00  CNR1797421769
#
#          Booking_Status Customer_ID Vehicle_Type Pickup_Location  \
# 0    Canceled by Driver   CID713523  Prime Sedan     Tumkur Road
# 1               Success   CID225428         Bike     Magadi Road
# 2               Success   CID270156    Prime SUV   Sahakar Nagar
# 3  Canceled by Customer   CID581320        eBike      HSR Layout
# 4               Success   CID939555         Mini     Rajajinagar
#
#   Drop_Location  V_TAT  C_TAT                    Canceled_Rides_by_Customer  \
# 0      RT Nagar    168     85                                Not applicable
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 103024 entries, 0 to 103023
# Data columns (total 19 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   Date                        103024 non-null  datetime64[us]
#  1   Time                        103024 non-null  datetime64[us]
#  2   Booking_ID                  103024 non-null  str
#  3   Booking_Status              103024 non-null  str
#  4   Customer_ID                 103024 non-null  str
#  5   Vehicle_Type                103024 non-null  str
#  6   Pickup_Location             103024 non-null  str
#  7   Drop_Location               103024 non-null  str
#  8   V_TAT                       103024 non-null  int64
#  9   C_TAT                       103024 non-null  int64
#  10  Canceled_Rides_by_Customer  103024 non-null  str
#  11  Canceled_Rides_by_Driver    103024 non-null  str
#  12  Incomplete_Rides            103024 non-null  str
# ...

# %% [markdown]
# ## Load data to SQL

# %%
from sqlalchemy import create_engine

engine = create_engine(
    "mysql+mysqlconnector://root:7708275323@localhost:3306/ola_project"
)

df.to_sql(
    name="ola_rides",
    con=engine,
    if_exists="append",
    index=False
)
print("Data uploaded successfully")
# Out:
# Data uploaded successfully
